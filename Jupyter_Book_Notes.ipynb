# %% [markdown]
# ## What have we tried?
# Canvas
# Gitbook
# Jupyter Notebooks uploaded to Github (doesn't make the pages)
# Leanpup
#
# ## What is the process now?
#
# ## What should the proess be?
# chapter and section indications are indicated in the jupyter book
# each book = one chapter. Sections are marked up in code
# Goal: generate HTML and PDF of Jupyter Notebooks using only Anaconda or other Python libraries
#
# copy java book into a content directory
#
#
# ## Goals of the project
# Create a book by converting Canvas to MD to JupyterBook to GitHubPages

# %% [markdown]
# talk about having a need to create textbooks, pdf and handouts and other course materials
#
# talking about finding an open source solution and modifying it to meet my needs
#
# talk about publishing my modified solution
#
#
#
# ### JupyterBook almost solves the problem but it has issues:
#
# * TOC must be created by hand
# * what is the purpose of jekyll on the writer's machine? Does it need to be installed or is this just for GitHub to * * generate a static site
# * Do I need ruby and GEM installed?
# * Can  I automate the process of creating an GitHub repo and comiting changes (maybe each time the book is generated?)
# * maybe create a script to prompt the user to enter the values for the configuration and update the configuration
# * the python script contains a lot of hard-coded values that could be put in a config file
# * The entire process is klunky and unclear - needs illustrated documentation
# * Could this process be turned into a web application so the user doesn't need to install anything? Or at least a docker container?
# * Automate creating the license file and don't default to open source
#
#
# ## How can I fix the issues?
#
# * write a script to create TOC dynamically by reading the markdown

# %%
# Markdown
What is Markdown and how do I write it?

Markdown is a wonderful language to write relatively simple documents that contain elements like sections, paragraphs, lists, links, and images, etc. Pandoc (http://pandoc.org) has greatly extended the original Markdown syntax, and added quite a few useful new features, such as footnotes, citations, and tables. More importantly, Pandoc makes it possible to generate output documents of a large variety of formats from Markdown, including HTML, LaTeX/PDF, Word, and slides.

# %% [markdown]
# # Anaconda
#
# Make sure you have the correct version of Anaconda. Create an environment for Python 3 if you don't have one or reinstall Anaconda. I choose to reinstall Anaconda since I don't want 2 anymore.
#
# ### How to uninstall Anaconda completely from MacOS
#
# #### To remove the configs:
# ```
# conda install anaconda-cleananaconda-clean --yes
# Once the configs are removed you can delete the anaconda install folder, usually under your home dir:
# ```
# ```
# rm -rf ~/anaconda2
# ```
# Also, the ```anaconda-clean --yes``` command creates a backup in your home directory of the format ```~/.anaconda_backup/<timestamp>```. Make sure to delete that one also.
#
# EDIT (v5.2.0): Now if you want to clean all, you will also have to delete the two last lines added to your .bash_profile. They look like:
#
# ``` added by Anaconda3 5.2.0 installerexport PATH="/Users/ody/anaconda3/bin:$PATH ```
#
# ### Required Python Packages
# ```
# pytest
# ruamel.yaml
# tqdm
# numpy
# pyyaml
# nbformat
# nbclean
# setuptools
# ```
#
# You can put the required dependencies above in a file and call that file at the Anaconda terminal prompt:
# ```conda env create -f environment.yml```
#
# ## Starting Anaconda and Jupyter Notebook
#
# Start Anaconda. Once Anaconda is running click on Base and click on terminal from the Anaconda Navigator.
#
# ![Anaconda Terminal](https://res.cloudinary.com/dkoqxjnsr/image/upload/v1550245684/AnacondaTerminal_u29vpy.png)
#
#
# Next, start Jupyter Notebook by entering ```jupyter notebook``` at the command line. Then check your python version (using jupyter notebook)
#
# ``` python
# import os
# print (os.getcwd())
#
# import sys
# sys.version
# sys.version_info
# ```
#
# Now that you have Jupyter Notebook working, leave Jupyter notebook and go back to the Anaconda terminal. You can actually do this in Jupyter Notebook but not today.

# %% [markdown]
# ## Setting up JupyterBook
#
#
#
# It seems you need Juptyer Hub. You *could* install it yourself... https://the-littlest-jupyterhub.readthedocs.io/en/latest/index.html
# The good news is, you can easily install Jupyter Hub from Anaconda 3 and selected JupyterHub install from the navigator so I didn't get into how to install it.... I just used it.
#
# >> You can also use Docker or Bitnami for Jupyter Hub
#
# ### Install JupyterBook in Anaconda
# 1. At the Anaconda prompt install the nbclean package: ```pip install nbclean```
# 2. At the Anaconda prompt install jupyter_book ```pip install jupyter_book```
# 2. Create a GitHub repository and edit the settings to make it a GitHub pages site
# 3. Create the content directory structure: ```jupyter book create mybook```
#     a. Add your content to mybook/content
#     b. Modify mybook/_data/toc.yml to match your content
#     c. Modify mybook/_config.yml to the configuration you’d like
# 3. Create the license.md file
# 5. Create the book's content in ```mybook/content``` either as markdown or as Jupyter notebooks
# 6. Generate the book from the Anaconda terminal: ```jupyter-book build mybook/```
# 4. Create the TOC (after you add content)
# > Note that if you choose to create the book template and
# > later add content to it, you can quickly generate a basic
# > Table of Contents by running the following command:
# > ```jupyter-book toc mybook```
# 4. Commit your book to Git and the push to GitHub
#     a. Change to the book directory and run ```git init```
#     b. Update the remote url
#         1.    ```git remote set-url remote https://username@github.com/github.com/username/repository.git```
#     c. Push to GitHub ```git push origin master```
#
# > GitHub will use Jekyll to build the repository when you push changes (if the site is a GitHub pages site)
#
#
# ### TOC
# The TOC is a yml (YAML) file which contains the order and numbering for all sections in the book.
# Each entry in the TOC follows the following schema:
#
#  - title: mytitle   # Title of chapter or section
#    url: /myurl  # URL of section relative to the /content/ folder.
#    sections:  # Contains a list of more entries that make up the chapter's sections
#    not_numbered: true  # if the section shouldn't have a number in the sidebar (e.g. Introduction or appendices)
#    expand_sections: true  # if you'd like the sections of this chapter to always be expanded in the sidebar.
#    external: true  # Whether the URL is an external link or points to content in the book
#
# > How should I name my files?
# > Your file name becomes the TOC topic title. Words should be separated by an underscore which is used to split words in the file name. If first part of the filename is a number for ordering, remove it
#
# #### Below are some special values that trigger specific behavior:
#  - search: true  # Will provide a link to a search page
#  - divider: true  # Will insert a divider in the sidebar
#  - header: My Header  # Will insert a header with no link in the sidebar
#
# > What is YAML?
# > https://pypi.org/project/ruamel.yaml/
# > YAML: YAML Ain't Markup Language
# > What It Is: YAML is a human friendly data serialization standard for all programming languages.
# > Do I need to install YAML? It get's imported into your python script for the TOC:
# ```from ruamel.yaml import YAML``` so ```pip install ruamel.yaml```
#
#
# #### How are Jupyter Notebooks processed?
#
# Each Jupyter notebook becomes one HTML page so it can be a complete chapter or a complete section but it will not be sub-divided.
#
#
# ### Generating the TOC from a Script
# This probably doesn't work and needs to be re-written. The script runs the
# file ```/scripts/generate_toc.py```
#
# > Sample file:
# > https://github.com/jupyter/jupyter-book/blob/master/jupyter_book/scripts/generate_toc.py
#
# You need to know the following:
# ```cmd
# args = parser.parse_args(sys.argv[2:])
# path_book = args.path_book
# path_content = op.join(path_book, 'content')
# path_toc = op.join(path_book, '_data', 'toc.yml')
# ```
#
# parser = argparse.ArgumentParser(description=DESCRIPTION)
# parser.add_argument("content_folder", default=None, help="Path to the folder where the textbook is stored.")
# parser.add_argument("--out_path", default=None, help="Path to the folder where the output toc.yml file will be written.")
# parser.add_argument("--filename_split_char", default='_', help="The character used to split words in the file name. Used to generate titles from file names. Defaults to '_'")
# parser.add_argument("--overwrite", action='store_true', help="Overwrite SUMMARY.md if it already exists.")

# %% [markdown]
# ### Configuration Files
# Some of the parameters are hard-coded and done so incorrectly because apparently nobody has heard of configuration files.
#
# In the file ```~/anaconda3/lib/python3.7/site-packages/jupyter_book/create.py```
#
# The minmal template doesn't actually exist. You can create one but for now simply change the line
#
# ```MINIMAL_PATH  = op.join(op.dirname(__file__), 'minimal')```
#
# to
# ```MINIMAL_PATH  = op.join(op.dirname(__file__), 'book_template')```
#
# and it will use the book_template as the minimal path. When you have more time you can copy the book_template to a folder called minimal and delete unwanted content files and change the above parameters back.
#
#
# You need to create a LICENSE.md file before you can create the book. You have to create a LICENSE.md file which can contain anything (your license terms or nothing, in my case). This should be placed in
# ```~/anaconda3/lib/python3.7/site-packages/jupyter_book/book_template``` directory

# %% [markdown]
# This config file is meant for settings that affect your whole blog, values
# which you are expected to set up once and rarely edit after that. If you find
# yourself editing this file very often, consider using Jekyll's data files
# feature for the data you need to update frequently.
#
# For technical reasons, this file is *NOT* reloaded automatically when you use
# 'bundle exec jekyll serve'. If you change this file, please restart the server process.
#
# Site settings
# These are used to personalize your new site. If you look in the HTML files,
# you will see them accessed via {{ site.title }}, {{ site.email }}, and so on.
# You can create any custom variable you would like, and they will be accessible
# in the templates via {{ site.myvariable }}.
#
# #######################################################################################
# ### Jekyll site settings
# title: Jupyter Book
# author: The Jupyter Book Community
# email: choldgraf@berkeley.edu
# description: >-
#   This is an example book built with Jupyter Books.
#
# baseurl: /jupyter-book   # the subpath of your site, e.g. /blog. If there is no subpath for your site, use an empty string ""
# url: https://jupyter.org   # the base hostname & protocol for your site, e.g. http://example.com
#
#
# #######################################################################################
# ### Jupyter Book settings
#
# ### Notebook content settings
# hide_cell_text: '# HIDDEN' #When building textbook cells with this text inside will be hidden in the output markdown
# hide_code_text: '# NO CODE'#When building textbook cells with this text inside will have *only* their output shown
# use_hide_code_button: true #If True, a button appears to the right of each cell that lets you hide its contents.
#
# ### Sidebar settings
# show_sidebar: true                # Show the sidebar. Only set to false if your only wish to host a single page.
# collapse_inactive_chapters: true  # Whether to collapse the inactive chapters in the sidebar
# textbook_logo: images/logo/logo.png  # A logo to be displayed at the top of your textbook sidebar
# textbook_logo_link: https://jupyter.org/jupyter-book/intro.html # A link for the logo.
# sidebar_footer_text: Powered by <a href="https://github.com/jupyter/jupyter-book">Jupyter Book</a>
# number_toc_chapters: true # Whether to add numbers to chapters in Table of Contents. If true, you can control this at the Chapter level in _data/toc.yml
#
# ### Search settings
# search_max_words_in_content: 100 # too many words will make search slow

# %% [markdown]
# ### Building (Creating) your own book
#
# https://jupyter.org/jupyter-book/guide/03_build.html
#
# ```jupyter-book build mybookname```

# %% [markdown]
# ### Book Content Directory Structure:
# The book content directories will be created when you
# You will create all your content in one or more Jupyter Notebooks or in markdown files. The notebooks and markdown can be placed under the content directory of your book.
#
# You can store Jupyter Notebooks and/or markdown in the content directory. You can put subdirectories in the content directory as well.
#
# ```
# mybook/
#
# ├── content
# │   ├── root_test.md
# │   └── tests
# ├── _data
# │   └── toc.yml
# ├── images
# │   └── tests
# ├── mylicense.md
# ├── myextrafolder
# │   └── myextrafile.txt
# └── config.yml
# ```

# %% [markdown]
# ### Done Writing? Generate your JupyterBook
# After all your content has been created, you need to generate the JupyterBook. It will be put into Github in a repository that will be set up as Github Pages site.
#
# From the Anaconda prompt, You can generate a Jupyter Book from it with the following command:
#
# then from the command prompt you can call:
#
# $jupyter-book create mybook
#
#
# ```cmd
# jupyter-book create mybookname --content-folder mybook/content \
#                                --toc mybook/_data/toc.yml \
#                                --config mybook/_config.yml \
#                                --license mybook/mylicense.md \
#                                --extra-files mybook/myextrafolder
#
# ```

# %% [markdown]
# ### Creating the TOC
#
# You have to create the TOC yourself or wait for me to write a script for it. The script should loop through the markdown files and generate the TOC or should create the TOC and markdown from a config file.
#
# If you want to have numbered sections and subsections in the sidebar of the TOC then create numbers in the directory structure
#
# The Minimal TOC is header and URL pointing to the markdown file (without the extension)
#
# Structure of the TOC
#
# The TOC file contains the order and numbering for all sections in the book.
#
# #### Each entry has the following schema:
# * title: mytitle # Title of chapter or section
# * url: /myurl # URL of section relative to the /content/ folder.
# * sections: # Contains a list of more entries that make up the chapter's sections
# * not_numbered: true # if the section shouldn't have a number in the sidebar (e.g. Introduction or appendices)
# * expand_sections: true # if you'd like the sections of this chapter to alwaysbe expanded in the sidebar.
# * external: true # Whether the URL is an external link or points to content in the book
#
# Below are some special values that trigger specific behavior:
# * search: true # Will provide a link to a search pag
# * divider: true # Will insert a divider in the sidebar
# * header: My Header # Will insert a header with no link in the sidebar
#
#
# ### Example TOC
# ```cmd
# - title: Home
#   url: /intro
#   not_numbered: true
# - title: Search
#   search: true
#
# - title: Getting started
#   url: /guide/01_overview
#   not_numbered: true
#   expand_sections: true
#   sections:
#   - title: Create your book
#     url: /guide/02_create
#   - title: Build and publish your book
#     url: /guide/03_build
#   - title: FAQ
#     url: /guide/04_faq
#   - title: How-to and advanced topics
#     url: /guide/05_advanced
#
# - title: Features and customization
#   url: /features/features
#   not_numbered: true
#   expand_sections: true
#   sections:
#   - title: Markdown files
#     url: /features/markdown
#     not_numbered: true
#   - title: Jupyter notebooks
#     url: /features/notebooks
#     not_numbered: true
#   - title: Hiding code blocks or entire cells
#     url: /features/hiding
#     not_numbered: true
#   - title: Connecting content with JupyterHub and Binder
#     url: /features/interact
#     not_numbered: true
#   - title: Citations and bibliographies
#     url: /features/citations
#     not_numbered: true
#   - title: Searching your book
#     url: /features/search
#     not_numbered: true
#
# - title: GitHub repository
#   url: https://github.com/jupyter/jupyter-book
#   external: true
#   not_numbered: true
#
# - divider: true
# - header: Demo textbook
#
# - title: Data Science
#   url: /01/what-is-data-science
#   sections:
#   - title: Introduction
#     url: /01/1/intro
#   - title: Why Data Science?
#     url: /01/2/why-data-science
#   - title: Plotting the Classics
#     url: /01/3/Plotting_the_Classics
#     subsections:
#     - title: Subsection Demo 1
#       url: /01/3/subsection/subsections
#     - title: Subsection Demo 2
#       url: /01/3/subsection/subsectiontwo
#
# - title: Causality and Experiments
#   url: /02/causality-and-experiments
#   sections:
#   - title: John Snow and the Broad Street Pump
#     url: /02/1/observation-and-visualization-john-snow-and-the-broad-street-pump
#   - title: "Snow\u2019s \u201CGrand Experiment\u201D"
#     url: /02/2/snow-s-grand-experiment
#   - title: Establishing Causality
#     url: /02/3/establishing-causality
#   - title: Randomization
#     url: /02/4/randomization
#   - title: Endnote
#     url: /02/5/endnote
# ```

# %%
## Thoughts on the process

This is kind of a klunky set-up.  I would rather create a jupyter notebook, save it a markdown and run a script which sets up the directories, etc.... maybe next time.

You can create content with markdown or with Jupyter Notebooks. The content for the current page is contained in a Jupyter Notebook in the notebooks/ folder of the repository. This means that we can include code blocks and their outputs, and export them to Jekyll markdown.

Images are a pain with Jupyter Notebooks because you can't just cut and paste..... however: Images are less of a pain with cloudinary. It hosts your images everywhere and forever and you can access your image via URL. So: Use Cloudinary. You're welcome!

Linking to an image from Markdown in Jupyter notebook: 
```'![Anaconda Terminal](https://res.cloudinary.com/dkoqxjnsr/image/upload/v1550245684/AnacondaTerminal_u29vpy.png)'```

# %%
## References
 * https://jupyter.org/jupyter-book/intro.html
 * https://hub.docker.com/r/jupyterhub/jupyterhub
 * https://www.dataquest.io/blog/docker-data-science/ <-- if you want to try docker

# %% [markdown]
# ## How to do this is python
#
# use nbconvert
# ```
# import pdfkit
# pdfkit.from_url('http://google.com', 'out.pdf')
# ```
#
# Highlighting source code syntax
# use https://code.google.com/archive/p/google-code-prettify/
